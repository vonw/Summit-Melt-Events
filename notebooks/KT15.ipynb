# %% [markdown]
# ## Notebook to view KT15 Snow Surface Temperature for melt event
#
#  by H Guy, 2019-11-08

# %% [markdown]
# #### Notes on the KT15:
#
# Model: KT15.85 II</br>
# Spectral range: 9.6 to 11.5 um</br>
# Calibration factor: 1.3932</br>
# Emissivity: 1</br>
# Response time: 1s</br>
# Accuracy: +/- 0.5C plus 0.7% of the temperature difference between the housing and the object to be measured

# %%
import pandas as pd
import numpy  as np
from bokeh.io import output_notebook, show
from bokeh.layouts import gridplot
from bokeh.palettes import Viridis3
from bokeh.plotting import figure
from bokeh.models import Title
from bokeh.models import Span

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
KT = pd.read_csv('../data/KT15/KT_2019-07-29_08-01',parse_dates=[0],index_col=[0],usecols=[0,1])

# %%
p1=figure(plot_width=1000,
       plot_height=400,
       y_axis_label='KT15 Skin Temperature (C)',
       x_axis_type='datetime',
       y_range=[-18, 3])

# Horizontal line
hline = Span(location=0, dimension='width', line_color='red', line_width=1)
p1.renderers.extend([hline])

p1.line(KT.index,KT['T'])

#p1.add_layout(Title(text="Heather Guy, 19 October 2019", text_font_style="italic"), 'above')
#p1.add_layout(Title(text="Snow pit from Summit Station"), 'above')

show(p1)
# Out:
#   <div class="bk-root" id="f1643a31-12a7-4e41-afd5-a4c770677d25" data-root-id="1002"></div>
